# %% [markdown]
# # Classiq Table of Contents

# %% [markdown]
# ## Algorithms:
#
# #### Algebraic:
# - [Hidden Shift](bin/algorithms/algebraic/hidden_shift/hidden_shift.ipynb)
#
# - [Shor](bin/algorithms/algebraic/shor/shor.ipynb)
#
# #### Amplitude Estimation:
# - [QMC User-Defined](bin/algorithms/amplitude_estimation/qmc_user_defined/qmc_user_defined.ipynb)
#
# - [Quantum Counting](bin/algorithms/amplitude_estimation/quantum_counting/quantum_counting.ipynb)
#
# #### Bernstein-Vazirani:
# - [Bernstein-Vazirani](bin/algorithms/bernstein_vazirani/bernstein_vazirani.ipynb)
#
# #### Deutsch-Jozsa:
# - [Deutsch-Jozsa](bin/algorithms/deutsch_jozsa/deutsch_jozsa.ipynb)
#
# #### Grover:
# - [3-SAT Grover](bin/algorithms/grover/3_sat_grover/3_sat_grover.ipynb)
#
# - [Large 3-SAT Grover](bin/algorithms/grover/3_sat_grover_large/3_sat_grover_large.ipynb)
#
# - [Max Cut Grover](bin/algorithms/grover/grover_max_cut/grover_max_cut.ipynb)
#
# #### HHL:
# - [HHL](bin/algorithms/hhl/hhl/hhl.ipynb)
#
# #### QML:
# - [QGAN](bin/algorithms/qml/qgan/qgan_bars_and_strips.ipynb)
#
# - [QSVM](bin/algorithms/qml/qsvm/qsvm.ipynb)
#
# - [QSVM Pauli Feature Map](bin/algorithms/qml/qsvm_pauli_feature_map/qsvm_pauli_feature_map.ipynb)
#
# - [Quantum AutoEncoder](bin/algorithms/qml/quantum_autoencoder/quantum_autoencoder.ipynb)
#
# #### QPE:
# - [QPE](bin/algorithms/qpe/qpe_for_matrix/qpe_for_matrix.ipynb)
#
# #### QSVT:
# - [Fixed-Point Amplitude Amplification](bin/algorithms/qsvt/qsvt_fixed_point_amplitude_amplification/qsvt_fixed_point_amplitude_amplification.ipynb)
#
# - [Matrix Inversion](bin/algorithms/qsvt/qsvt_matrix_inversion/qsvt_matrix_inversion.ipynb)
#
# #### Simon:
# - [Simon](bin/algorithms/simon/simon.ipynb)
#
# #### Swap Test:
# - [Swap Test](bin/algorithms/swap_test/swap_test.ipynb)
#
#
#
# ## Applications:
#
# #### Benchmarking:
# - [Quantum Volume](bin/applications/benchmarking/quantum_volume/quantum_volume.ipynb)
#
# - [Randomized Benchmarking](bin/applications/benchmarking/randomized_benchmarking/randomized_benchmarking.ipynb)
#
# #### Chemistry:
# - [Molecular Energy Curve](bin/applications/chemistry/molecular_energy_curve/molecular_energy_curve.ipynb)
#
# - [Molecular Eigensolver](bin/applications/chemistry/molecule_eigensolver/molecule_eigensolver.ipynb)
#
# - [Protein Folding](bin/applications/chemistry/protein_folding/protein_folding.ipynb)
#
# - [QPE For Molecules](bin/applications/chemistry/qpe_for_molecules/qpe_for_molecules.ipynb)
#
# - [Second Quantized Hamiltonian](bin/applications/chemistry/second_quantized_hamiltonian/second_quantized_hamiltonian.ipynb)
#
# #### Cybersecurity:
# - [Link Monitoring](bin/applications/cybersecurity/link_monitoring/link_monitoring.ipynb)
#
# - [Patching Management](bin/applications/cybersecurity/patching_management/patching_managment.ipynb)
#
# - [Whitebox Fuzzing](bin/applications/cybersecurity/whitebox_fuzzing/whitebox_fuzzing.ipynb)
#
# #### Finance:
# - [Credit Card Fraud](bin/applications/finance/credit_card_fraud/credit_card_fraud.ipynb)
#
# - [Option Pricing](bin/applications/finance/option_pricing/option_pricing.ipynb)
#
# - [Portfolio Optimization](bin/applications/finance/portfolio_optimization/portfolio_optimization.ipynb)
#
# #### Logistics:
# - [Facility Location](bin/applications/logistics/facility_location/facility_location.ipynb)
#
# - [Task Scheduling Program](bin/applications/logistics/task_scheduling_problem/task_scheduling_problem.ipynb)
#
# - [Traveling Salesman Problem](bin/applications/logistics/traveling_salesman_problem/traveling_saleman_problem.json)
#
# #### Optimization:
# - [Electric Grid Optimization](bin/applications/optimization/electric_grid_optimization/electric_grid_optimization.ipynb)
#
# - [Integer Linear Programming](bin/applications/optimization/integer_linear_programming/integer_linear_programming.ipynb)
#
# - [Knapsack Binary](bin/applications/optimization/knapsack_binary/knapsack_binary.ipynb)
#
# - [Knapsack Integer](bin/applications/optimization/knapsack_integer/knapsack_integer.ipynb)
#
# - [Max Clique](bin/applications/optimization/max_clique/max_clique.ipynb)
#
# - [Max Cut](bin/applications/optimization/max_cut/max_cut.ipynb)
#
# - [Max Independent Set](bin/applications/optimization/max_independent_set/max_independent_set.ipynb)
#
# - [Max Induced k-Color Subgraph](bin/applications/optimization/max_induced_k_color_subgraph/max_induced_k_color_subgraph.ipynb)
#
# - [Max k-Vertex Cover](bin/applications/optimization/max_k_vertex_cover/max_k_vertex_cover.ipynb)
#
# - [Min Graph Coloring](bin/applications/optimization/min_graph_coloring/min_graph_coloring.ipynb)
#
# - [Min Dominating Set](bin/applications/optimization/minimum_dominating_set/minimum_dominating_set.ipynb)
#
# - [Set Cover](bin/applications/optimization/set_cover/set_cover.ipynb)
#
# - [Set Partition](bin/applications/optimization/set_partition/set_partition.ipynb)
#
# #### Physical Systems:
# - [Ising Model](bin/applications/physical_systems/ising_model/ising_model.ipynb)
#
# ## Built-In Apps:
# - [Chemistry](bin/built_in_apps/chemistry/chemistry.ipynb)
#
# - [Grover](bin/built_in_apps/grover/grover.ipynb)
#
# - [Option Pricing](bin/built_in_apps/option_pricing/option_pricing.ipynb)
